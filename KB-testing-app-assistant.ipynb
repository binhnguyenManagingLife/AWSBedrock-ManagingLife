# %% [markdown]
# # App Assistant
# - This notebook is to replicate what we were able to achieve on the AWS console
# - Creating through bedrock-agent for more confirugation and control

# %%
import boto3
import sys
import json
import pprint
from botocore.client import Config
from botocore.exceptions import NoCredentialsError, PartialCredentialsError, ClientError
import os
import random
from retrying import retry
import time
from utility import *
print('Running boto3 version:', boto3.__version__)
# Out:
# Running boto3 version: 1.35.34

# %%
# Create bedrock agent client
boto3_session = boto3.session.Session()
region_name = boto3_session.region_name or 'ca-central-1'
bedrock_config = Config(connect_timeout=120, read_timeout=120, retries={'max_attempts': 0}, region_name=region_name)
bedrock_agent_client = boto3_session.client("bedrock-agent-runtime", config=bedrock_config)

# Define FM to be used for generations 
model_id = "anthropic.claude-3-sonnet-20240229-v1:0" 
model_arn = f'arn:aws:bedrock:{region_name}::foundation-model/{model_id}'

# knowledge-base-app-assistant
kb_id = 'KESDTCXEJE'

# %%
# R and G is to `retrieve_and_generate`
def retrieve_and_generate(query, kb_id, model_arn, max_results, prompt_template):
    response = bedrock_agent_client.retrieve_and_generate(
            input={
                'text': query
            },
        retrieveAndGenerateConfiguration={
        'type': 'KNOWLEDGE_BASE',
        'knowledgeBaseConfiguration': {
            'knowledgeBaseId': kb_id,
            'modelArn': model_arn,

            # Retrieval Configuration
            'retrievalConfiguration': {
                'vectorSearchConfiguration': {
                    'numberOfResults': max_results,
                    'overrideSearchType': 'HYBRID' or 'SEMANTIC'
                    }
                }, 

            # Generation Configuration
            'generationConfiguration': {
                    'promptTemplate': {
                        'textPromptTemplate': prompt_template
                    } ,
                    'inferenceConfig': {
                    'textInferenceConfig': {
                        'maxTokens': 512,
                        'temperature': 1.0,
                        'topP': 1.0
                        }
                    }
                },

            # Orchestration Confirugation
            'orchestrationConfiguration': {
                'queryTransformationConfiguration': {
                    'type': 'QUERY_DECOMPOSITION'
                    }
                } 
            
            } # Knowledge base configuration
        }
    )
    return response


# Printing Generation Results refers to the citations / references from the KB
def print_generation_results(query, response, print_context = False):
    generated_text = response['output']['text']
    print (query)
    print(generated_text)
    
    if print_context is True:
        ## print out the source attribution/citations from the original documents to see if the response generated belongs to the context.
        citations = response["citations"]
        contexts = []
        for citation in citations:
            retrievedReferences = citation["retrievedReferences"]
            for reference in retrievedReferences:
                contexts.append(reference["content"]["text"])
    
        print('\n\n\nRetrieved Context:\n')
        pprint.pp(contexts)

# %% [markdown]
# # Test with potential questions

# %%
# Assigning the default knowledge base prompt

path = '../machine-learning/4. Knowledge Base Template/'
# filename = 'RoleSwitching_V4_Oct2.md'
filename = 'App_Assistant_V1_Oct10.md'

with open(path+filename, 'r') as f:
    prompt_template = f.read()

# %%
path = '../machine-learning/6. Test Cases/App Assistant/'
filename = 'Potential-Questions2.md'

with open(path+filename, 'r') as f:
    questions = f.read()

queries = questions.split('\n')

for i in queries:
    response = retrieve_and_generate(query = i, kb_id = kb_id, model_arn = model_arn, max_results = 10, prompt_template = prompt_template)
    print_generation_results(i, response)
    print ('---------------------------------------------------- \n')

# %%
path = '../machine-learning/6. Test Cases/App Assistant/'
filename = 'Potential-Questions3.md'

with open(path+filename, 'r') as f:
    questions = f.read()

queries = questions.split('\n')

for i in queries:
    response = retrieve_and_generate(query = i, kb_id = kb_id, model_arn = model_arn, max_results = 10, prompt_template = prompt_template)
    print_generation_results(i, response)
    print ('---------------------------------------------------- \n')

# %%
path = '../machine-learning/6. Test Cases/App Assistant/'
filename = 'Potential-Questions4-Unrelated.md'

with open(path+filename, 'r') as f:
    questions = f.read()

queries = questions.split('\n')

for i in queries:
    response = retrieve_and_generate(query = i, kb_id = kb_id, model_arn = model_arn, max_results = 10, prompt_template = prompt_template)
    print_generation_results(i, response)
    print ('---------------------------------------------------- \n')

# %% [markdown]
# # Using bedrock runtime NOT agent

# %%
# Bedrock Agent runtime
pp = pprint.PrettyPrinter(indent=2)
session = boto3.session.Session()
region = 'ca-central-1'
bedrock_config = Config(connect_timeout=120, read_timeout=120, retries={'max_attempts': 0})
bedrock_client = boto3.client('bedrock-runtime', region_name = region)
bedrock_agent_client = boto3.client("bedrock-agent-runtime", config=bedrock_config, region_name = region)

# KB ID
kb_id = 'KESDTCXEJE'

# %%
def retrieve(query, kbId, numberOfResults=5):
    return bedrock_agent_client.retrieve(
        retrievalQuery= {
            'text': query
        },
        knowledgeBaseId=kbId,
        retrievalConfiguration= {
            'vectorSearchConfiguration': {
                'numberOfResults': numberOfResults,
                'overrideSearchType': "HYBRID", # optional
            }
        }
    )

def get_contexts(retrievalResults):
    contexts = []
    for retrievedResult in retrievalResults: 
        contexts.append(retrievedResult['content']['text'])
    return contexts

# %%
# Assigning the default knowledge base prompt

path = '../machine-learning/4. Knowledge Base Template/'
filename = 'App_Assistant_V1_Oct10.md'

with open(path+filename, 'r') as f:
    prompt_template = f.read()

# %%
# Loading the questions that we want to ask

path = '../machine-learning/6. Test Cases/App Assistant/'
filename = 'Potential-Questions2.md'

with open(path+filename, 'r') as f:
    questions = f.read()

queries = questions.split('\n')


# Going through the queries to send to LLM

for query in queries:
    print ('---------------------------------------------------- \n')

    # Acquire the context
    response = retrieve(query, kb_id)
    retrievalResults = response['retrievalResults']
    contexts = get_contexts(retrievalResults)

    # Create the prompt
    prompt = f"""
    Human: Use the following <context> to answer the <query> according to your role in <prompt_template>. 
    <prompt_template>
    {prompt_template}
    </prompt_template>
    
    <context>
    {contexts}
    </context>
    
    <query>
    {query}
    </query>
    
    Do not respond if the prompt is not related to the app.
    
    Assistant:"""

    # Prepare the information to be invoked into the model
    messages=[{ "role":'user', "content":[{'type':'text','text': prompt.format(prompt_template, contexts, query)}]}]
    sonnet_payload = json.dumps({
        "anthropic_version": "bedrock-2023-05-31",
        "max_tokens": 512,
        "messages": messages,
        "temperature": 1,
        "top_p": 1
            }  )
    modelId = 'anthropic.claude-3-sonnet-20240229-v1:0' 
    accept = 'application/json'
    contentType = 'application/json'
    response = bedrock_client.invoke_model(body=sonnet_payload, 
                                           modelId=modelId, 
                                           accept=accept, 
                                           contentType=contentType)

    # Call and print the response
    response_body = json.loads(response.get('body').read())
    response_text = response_body.get('content')[0]['text']
    # pp.pprint (query)
    # pp.pprint(response_text)
    print (query)
    print (response_text)
# Out:
# ----------------------------------------------------
#
# Is it possible to customize the app without logging in?
# Yes, you can personalize the application without logging in to the app. The context states: "Can I personalize the application without logging in to the app? Yes, you can personalize the application without logging in to the app."
# ----------------------------------------------------
#
# Am I required to accept the End User License Agreement?
# Yes, accepting the End User License Agreement is required to use the Manage My Pain app. The context states: "After the Intro, you will be shown our End User License Agreement. This will make sure that you understand the terms and conditions of using Manage My Pain. Press "Agree" and you can start using the application."
# ----------------------------------------------------
#
# Why isn’t my specific pain condition listed?
# Our users have added thousands of conditions, but we just show the most common ones in the app. If you can't find the condition that suits your situation, you can simply add it by following these steps:
#
# 1. Go to the "My Profile" section and expand the "Pain Conditions" list.
# 2. Tap the "Add New" button.
# 3. Type in three or more letters of your condition's name and wait for the search results.
# 4. If your condition is not in the list, tap "Add Condition" to manually enter it.
# 5. Provide details like first symptom date and diagnosis date if applicable.
# 6. Tap "Apply Changes" to save the new condition to your profile.
#
# The app allows you to customize and track any pain condition you have. Do you want me to provide more details on how to add or manage your conditions?
# ----------------------------------------------------
#
# Do I need to include any pain conditions?
# No, you do not have to add any pain conditions to use the Manage My Pain app. All information entered is voluntary. However, the app states that entering more information about your conditions and medications allows the reports generated to be more powerful and better communicate your situation.
# ----------------------------------------------------
#
# Why are you asking this question?
# The question "Why are you asking me this?" is referring to the personalization questions asked during the setup of the Manage My Pain app. According to the context provided, the app asks these questions to configure itself better to suit the user's situation, and to ensure that the reports generated are more relevant and informative for communicating with healthcare providers.
#
# Specifically, it states: "This information allows us to configure the application to better suit your situation, and ensures that the reports generated from Manage My Pain are a better communication tool."
#
# So in summary, the app asks personalization questions upfront to tailor the experience and reporting to the individual user's needs related to tracking and managing their pain.
# ----------------------------------------------------
#
# Am I obligated to add medications?
# No, you are not obligated to add medications in the app. Adding medications is optional. The app allows you to track your medications if you want to, but it is not a requirement for using the app.
# ----------------------------------------------------
#
# Why can't I find my medication in the list?
# Our database supports thousands of medications and brands, but we may have missed yours. If you can't find your medication in the list, you can request it to be added to our database. Here are the steps to request adding a new medication:
#
# 1. Go to the "Add Medication" screen by pressing "ADD NEW" either from the Home screen, My Profile screen, or when adding a new pain record.
#
# 2. Search for your medication by typing at least 3 letters of the name. If your medication doesn't appear in the search results, press the "REQUEST IT" button.
#
# 3. This will open your default email app with pre-filled information. Just press send to submit the request for us to add your medication.
#
# Do you want to learn more about tracking medications in the app?
# ----------------------------------------------------
#
# What measures do you take to secure my data?
# The app takes multiple measures to secure your data, including:
#
# - Transmitting data through a secure socket layer and using encrypted credentials for user authentication
# - Encrypting all data in transit and at rest
# - Having policies and procedures for system safeguards, access controls, and regular security audits
# - Backing up data daily off-site through an encrypted channel
# - Implementing privacy procedures with an assigned privacy officer
# - Restricting access to protected health information to only authorized personnel
# - Storing data on secure AWS servers with firewalls and physical security measures
#
# The company follows data protection guidelines like PIPEDA in Canada and HIPAA in the US to ensure the security and privacy of your information. Do you want to learn more about how your data is protected?
# ----------------------------------------------------
#
# Where can I find my activation email?
# If you do not receive an activation email after registering for an account with Manage My Pain, please check your spam or junk folder, as sometimes the activation email may end up there. The activation email contains a link that you need to click in order to activate your account.
# ----------------------------------------------------
#
# Will you share any of my personal information?
# No, we will never disclose any of your personal information. This is clearly stated in our Privacy Policy which details how we protect and use your information. We take privacy very seriously and do not share your email address or any other personal details with third parties.
# ----------------------------------------------------
#
# Will I receive unsolicited emails or spam from you?
# No, we never share your email address or send you unsolicited emails or spam. According to the information provided, the app will only email you for specific actions like changing your password or requesting a report. Occasionally, they may send out an email newsletter, but you can unsubscribe from that using the link at the bottom of those emails. Your privacy is protected and your email will not be misused or shared.
# ----------------------------------------------------
#
# Is it necessary to create multiple accounts?
# No, you do not need to create more than one account. The app allows you to use a single account across all your devices, and your data will be synchronized across them.
# ----------------------------------------------------
#
# When should I log a pain entry?
# There are a few common times when you should log a pain entry in the app:
#
# 1. When you receive a notification, which is typically set for 8PM every day. Clicking the notification will take you straight to the "Add Pain Record" screen.
#
# 2. When you start experiencing a new pain episode. You can add the initial details, then go back later and update the record with more information like duration, alleviating factors, etc. once the episode has ended.
#
# 3. Immediately after a pain episode ends. Adding the record right away allows you to accurately capture when it started, what interventions you tried, and other details while it's still fresh in your mind.
#
# You can also log baseline or constant pain by selecting the "All Day" option in the Timing section, which will create a 24-hour pain record starting at midnight.
#
# Let me know if you need any other details on when or how to log pain entries in the app.
# ----------------------------------------------------
#
# How can I enter baseline or constant pain data?
# To add baseline or constant pain, you can select the "All Day" option in the Timing section when adding a pain record. This will automatically create a record that begins at 12AM and lasts for 24 hours, allowing you to track your constant or baseline pain level accurately.
#
# The instructions state: "In the Timing section, there is an option to select "All Day", which automatically creates a pain record that begins at 12AM and lasts 24 hours. We recommend that you create this record every day for the most accurate Results."
#
# Do you want to learn more about adding pain records in the app?
# ----------------------------------------------------
#
# Can I assign different ratings for pain in various locations?
# Yes, you can assign different pain ratings for various locations in the app. The app allows you to create separate entries for different body locations, so you can rate the pain level for each location independently. This approach helps ensure accurate tracking and reporting of your pain experience.
# ----------------------------------------------------
#
# What should I do if a specific value is missing?
# If a specific value is missing from the lists in the app (e.g. medication name, symptom, activity), you can add a custom value to that list. The instructions mention that the app provides a starting list of common values based on clinically-validated sources, but you can add your own custom values if needed. To add a custom value:
#
# 1. Go to the Add Pain Record or Add Daily Reflection screen.
# 2. Expand the section you want to customize by pressing the down arrow.
# 3. Scroll down and click "EDIT LIST".
# 4. At the bottom, click "Add New".
# 5. Enter the value you want to add.
# 6. Click "ADD NEW" to save the custom value.
#
# After adding the custom value, it will appear in the list for you to select when logging symptoms, medications, etc. The instructions state that editing or deleting custom values will affect any existing records associated with that value, so be mindful of that.
#
# Do you want to learn more about customizing lists in the app?
# ----------------------------------------------------
#
# How can I log a past record?
# To log a past pain record in the Manage My Pain app, you have two options:
#
# 1. On the "Add Pain Record" screen, click the words "right now" in the question "How is your pain right now?". This will allow you to change the start date and time for the pain record.
#
# 2. On the "Add Pain Record" screen, open the "Timing" section and manually change the start date and start time to reflect when the pain episode occurred in the past.
#
# After adjusting the timing, you can fill out the other sections like locations, symptoms, treatments, etc. to fully document the past pain record. Then simply save the record when finished.
#
# Do you want to learn more about logging past pain records or any other features of the app?
# ----------------------------------------------------
#
# When is it appropriate to update an existing record?
# According to the context provided, it is appropriate to update an existing record in the following situations:
#
# 1. Many users come back after several hours to update the end time of their pain episode and the effectiveness of the medications and non-medication interventions they took.
#
# 2. To edit information in a previously saved pain record. The steps are:
# - On the home screen, long press the record you want to edit to open the editing options.
# - Or go to the Records tab in the Results screen, tap the three dot menu next to the record and select Edit.
# - Make the desired changes by expanding the relevant sections.
# - Save the updated record.
#
# Do you want to learn more about how to update or edit existing pain records in the app?
# ----------------------------------------------------
#
# Can I track more than just pain?
# Yes, you can track things other than just pain using the Manage My Pain app. The app allows you to add custom values to the "Other Associated Symptoms" section of a pain record. For example, if you want to track your mood, you can add custom values like "Mood (anxious)", "Mood (happy)", etc. in that section when recording your pain. This way, you can track other symptoms or factors along with your pain. The app is flexible and allows you to customize the tracking to suit your needs. Do you want to learn more about tracking additional symptoms and details?
# ----------------------------------------------------
#
# What if the value I need is not available?
# If the value you need is not available in the list, the app allows you to add a custom value. Here are the steps:
#
# 1. Go to the "Add Pain Record" or "Add Daily Reflection" screen where you want to customize the list.
# 2. Expand the section you want to customize by pressing the down arrow icon.
# 3. Scroll down and tap "EDIT LIST" to go to the "Edit List" screen.
# 4. At the bottom, tap "Add New" to enter a new custom value.
# 5. Enter the value you need and tap "ADD NEW" to save it.
# 6. The new custom value will now be available in the list.
#
# The ability to add custom values allows you to personalize the app to best fit your needs. Let me know if you need any clarification or have additional questions!
# ----------------------------------------------------
#
# When is the right time to add a daily reflection?
# According to the context provided, you should add a daily reflection closer to the end of your day, prior to going to bed. Doing so allows you to reflect on everything you accomplished during the day. The app states that "You should add a daily reflection closer to the end of your day prior to going to bed. Doing so at this time allows you to reflect on everything you accomplished during the day."
# ----------------------------------------------------
#
# How do I enter a daily reflection for a previous date?
# To enter a daily reflection for a previous date, follow these steps:
#
# 1. Open the app and navigate to the "Add Record" screen.
#
# 2. Select "Daily Reflection" from the record types.
#
# 3. On the "Add Daily Reflection" screen, expand the "Date and Time" section.
#
# 4. Tap on the date field and select the previous date you want to enter the reflection for.
#
# 5. Fill out the other sections of the daily reflection as needed.
#
# 6. Tap "Save" at the bottom of the screen to save the daily reflection for the selected previous date.
#
# This allows you to log daily reflections for past dates as needed. Let me know if you need any clarification or have additional questions!
# ----------------------------------------------------
#
# What happens if I don't add a daily reflection?
# The Daily Reflection scores are an important measurement for you and your healthcare team to understand the impact that pain is having on your life. While entering information in the Manage My Pain app is voluntary, the more data you provide, the more comprehensive and powerful the reports will be. So while not strictly required, adding daily reflections regularly is highly recommended to get the most value out of the app.
# ----------------------------------------------------
#
# How can I include a medication in the list?
# To include a medication in the list, you have a few options:
#
# 1. Search for the medication: Type three or more letters of the generic medication name or brand name, and wait for a few seconds. A list of medications will appear. Select the appropriate medication from the list to add it.
#
# 2. Add a new medication: If you can't find the medication in the search results, press "ADD NEW". This will take you to the "Add Medication" screen where you can search again. If the medication still doesn't appear in the search results, press "REQUEST IT". This will open your default email app with pre-filled information so you can send a request to have the medication added to the database.
#
# 3. Enter medication details: After selecting or adding the medication, you can specify additional details like brand, form, dosage, strength, and the conditions you're taking it for. Be sure to include the start and end dates. Press "APPLY CHANGES" to confirm.
#
# 4. The medication will now be included in your list and available to track when adding pain records.
#
# Do you want to learn more about adding or tracking medications in the app?
# ----------------------------------------------------
#
# Why am I unable to find the option I’m looking for?
# Here are a few possible reasons why you may be unable to find an option you're looking for in the app:
#
# 1. It's a custom value that needs to be added manually. The app allows you to add custom values for things like medications, symptoms, etc that are not initially included in the database. To add a new custom value, go to the relevant section, expand it, and select "Add New".
#
# 2. The specific brand/formulation of medication may not be in the database yet. However, you can usually find the active ingredient(s) and select those instead. If the ingredient itself is missing, you can add that as a custom value under "Interventions".
#
# 3. For some less common conditions/symptoms, the app's lists may not have all options covered initially. In that case, you can add missing items as custom values within the relevant section.
#
# 4. The feature you're looking for may not have been implemented yet. The app documentation mentions that some features like medication reminders are still being worked on.
#
# If you've checked all the relevant sections and still can't find what you need, I'd recommend contacting customer support via the "Contact Us" option in the app menu. They can look into adding the missing items to the database.
#
# Do you want to learn more about adding custom values or reaching out to the support team? Let me know if you need any additional details.
# ----------------------------------------------------
#
# Will modifying a custom value impact related records?
# Yes, editing a custom value will impact all records that were previously associated with that custom value. When modifying an existing custom value, the app will show a confirmation prompt indicating how many records will be affected before allowing you to proceed with the change.
# ----------------------------------------------------
#
# Am I required to rate the app when the prompt appears?
# No, rating the app is optional when the prompt appears. However, providing a rating is an important way to help the developers improve the app for you and other users.
# ----------------------------------------------------
#
# How can I confirm if my records are synchronized?
# To confirm if your records are synchronized:
#
# Every time you add a new record, it will automatically be sent to the server for synchronization. If the sync is still pending, a green dot will appear on top of the "sync" icon. This means there are changes that have not yet been saved to your account.
#
# To manually force the synchronization, press the "sync" icon. If the dot disappears and the icon turns green, your records have been successfully synced.
#
# However, if the "sync" icon remains red after pressing it, there were problems saving the record to your account. In that case, you should contact support for assistance.
#
# Do you want me to explain the synchronization process in more detail?
# ----------------------------------------------------
#
# Why can’t I see all of my records?
# You most likely have a filter applied which is limiting the records you can see. To see all your records, go to the "Filter Records" screen and press "RESET FILTERS" on the top-right side. This will remove any filters that were previously applied, allowing you to view all your pain records and daily reflections. If you still don't see all your records after resetting the filters, please contact support.
# ----------------------------------------------------
#
# Are records older than 30 days still available for free users?
# Yes, records older than 30 days are still accessible for free users. While the Insights, Reports, and Charts are limited to the last 30 days for free users, all your records remain available and visible under the Records tab.
# ----------------------------------------------------
#
# How were these reports generated?
# These reports were designed in collaboration with a multi-disciplinary pain management team at a major academic hospital. The reports aim to provide summarized and clinically relevant information to help healthcare professionals quickly understand the patient's condition and make more informed treatment or diagnosis decisions. Some key points about the report generation:
#
# - The Pain Summary includes 12 cards with graphs, charts, and frequency values summarizing the user's recorded pain data and daily reflections.
#
# - The Patient Profile and Record Details sections provide an overview of the user's profile information, conditions, medications, and detailed pain record entries.
#
# - Users can customize which sections to include by selecting overlays, sorting options, date ranges, etc.
#
# - For the free "Lite" version, users have access to the basic sections. Advanced sections like Calendar View require purchasing credits.
#
# - The reports are designed to present information healthcare providers typically collect from patients during visits, in an organized and shareable format.
#
# The overall goal is to facilitate better communication and understanding between patients and their care teams regarding their pain condition and management. Let me know if you need any clarification or have additional questions!
# ----------------------------------------------------
#
# What’s the best way to send my report to my doctor?
# The best way to share your report with your doctor is to print it out and bring it with you to your next clinical visit. The app recommends against emailing the report, as that is not a secure form of communication.
# ----------------------------------------------------
#
# How can I export these visual graphs?
# All graphs, including the timeline and calendar views, are available as sections in the Reports. However, please note that if you wish to include the Charts, Timeline, or Calendar views in the report, it will require a credit from a paid subscription.
# ----------------------------------------------------
#
# Why is there a credit charge for generating reports?
# According to the information provided, there is a credit charge for generating reports that include certain advanced sections, such as Charts, Timeline View, or Calendar View. The reasoning is:
#
# - The most commonly used section needed by healthcare professionals is the "Summary", which does not require a credit.
# - Credits are a way for "Lite" users to generate more comprehensive reports without having to purchase the full "Pro" version of the app.
# - It is also a way for the app developers to continue supporting and providing the more detailed advanced sections, which are only needed by a small segment of users.
#
# So in summary, the credit charge applies only if you want to include the advanced visualization sections in your report. The basic sections like Pain Summary, Patient Profile, and Record Details can be included for free. The credit system allows flexibility for users who only occasionally need the advanced reporting features.
#
# Do you want me to provide any additional details on the credit system for reports?
# ----------------------------------------------------
#
# Why am I missing some of my records?
# You're most likely missing some of your records because you have a filter applied that is hiding certain records. The app allows you to filter your records based on various criteria like timing, severity, pain conditions, etc. To view all your records:
#
# 1. Go to the "Records" or "Reports" tab in the app.
# 2. Tap the "funnel" icon on the top right to access the Filter Records screen.
# 3. On the Filter Records screen, tap "RESET FILTERS" to remove any applied filters.
#
# This will clear any filters you had set, allowing you to see all your pain records and daily reflections.
#
# If you still don't see certain records after resetting filters, you may want to check that you have not accidentally deleted or edited those records. Let me know if you need any other help!
# ----------------------------------------------------
#
# What are the benefits of including the advanced sections in the report?
# The more comprehensive sections like the Charts, Timeline, and Calendar views provide additional details and visual representations of your pain information. This can be useful when:
#
# - Explaining your condition for the first time to a new healthcare provider. The visuals give them a clearer picture of your symptoms and how they have progressed over time.
#
# - You need more documentation to support a claim or case related to your condition. The advanced sections provide greater detail than just the summary section.
#
# Many users find these extra views helpful to better communicate the full scope of their condition. They provide insight that may not be obvious from the summary cards alone. Do you want to learn more about generating reports with the advanced sections?
# ----------------------------------------------------
#
# How do I export all my data?
# Unfortunately the app does not currently offer the ability to export your data to CSV or any other raw data format. The only way to export your data is by generating a report from within the app. I would suggest generating a comprehensive report that includes all sections like the Charts, Timeline, Calendar, etc. to get a complete record of your data that can then be printed or shared. Let me know if you need any help on how to generate a report with all your information.
# ----------------------------------------------------
#
# How often will I need to buy credits?
# Credits are only needed if you wish to generate a report that includes the more comprehensive sections like Charts, Timeline View, or Calendar. For Lite users, credits are also required to include records older than 30 days in the report. Pro Subscribers do not need credits to generate full reports with advanced sections or include older records.
#
# The frequency of purchasing credits depends on how often you need to generate reports with those advanced sections. If you plan to generate many such reports, subscribing to the Pro plan may be more cost-effective. Do you want to learn more about credits and subscription plans?
# ----------------------------------------------------
#
# Which version or subscription plan would suit me best?
# When choosing a subscription plan, consider your needs and how frequently you may need to generate full reports with advanced analytics and insights. The app offers two main options:
#
# Lite Version (Free):
# - Allows you to log symptoms, track medications, and access basic features
# - Requires purchasing report credits to generate full reports with advanced sections
#
# Pro Subscription:
# - Provides unlimited access to generate full reports with advanced analytics and insights, without needing to purchase report credits
# - Offers a convenient monthly or yearly subscription model
#
# To decide, ask yourself how often you anticipate needing detailed reports and data analysis. If you only need occasional reports, the free Lite version with purchasing credits as needed may suffice. However, if you require regular in-depth reporting, the Pro Subscription could be more cost-effective in the long run.
#
# Do you want me to explain further about the subscription options and pricing? I'm happy to provide additional details to help you assess which plan may be the best fit.
# ----------------------------------------------------
#
# Do the credits I buy have an expiration date?
# No, the credits you purchase for Manage My Pain do not have an expiration date, according to the information provided:
#
# "Is there an expiration date for my purchased credits? No, there is no expiration date for your purchased credits."

# %%
# Loading the questions that we want to ask

path = '../machine-learning/6. Test Cases/App Assistant/'
filename = 'Potential-Questions3.md'

with open(path+filename, 'r') as f:
    questions = f.read()

queries = questions.split('\n')


# Going through the queries to send to LLM

for query in queries:
    print ('---------------------------------------------------- \n')

    # Acquire the context
    response = retrieve(query, kb_id)
    retrievalResults = response['retrievalResults']
    contexts = get_contexts(retrievalResults)

    # Create the prompt
    prompt = f"""
    Human: Use the following <context> to answer the <query> according to your role in <prompt_template>. 
    <prompt_template>
    {prompt_template}
    </prompt_template>
    
    <context>
    {contexts}
    </context>
    
    <query>
    {query}
    </query>
    
    Do not respond if the prompt is not related to the app.
    
    Assistant:"""

    # Prepare the information to be invoked into the model
    messages=[{ "role":'user', "content":[{'type':'text','text': prompt.format(prompt_template, contexts, query)}]}]
    sonnet_payload = json.dumps({
        "anthropic_version": "bedrock-2023-05-31",
        "max_tokens": 512,
        "messages": messages,
        "temperature": 1,
        "top_p": 1
            }  )
    modelId = 'anthropic.claude-3-sonnet-20240229-v1:0' 
    accept = 'application/json'
    contentType = 'application/json'
    response = bedrock_client.invoke_model(body=sonnet_payload, 
                                           modelId=modelId, 
                                           accept=accept, 
                                           contentType=contentType)

    # Call and print the response
    response_body = json.loads(response.get('body').read())
    response_text = response_body.get('content')[0]['text']
    # pp.pprint (query)
    # pp.pprint(response_text)
    print (query)
    print (response_text)
# Out:
# ----------------------------------------------------
#
# Will any of my personal information be shared?
# No, your personal information will never be shared or disclosed to anyone without your explicit consent. The app's privacy policy clearly states that it protects and does not share users' personal data with third parties. Your information is securely stored and encrypted, with strict access controls to ensure your privacy is maintained. You have full control over your data and who it is shared with.
# ----------------------------------------------------
#
# Do I need to use the same email for both my Google and Facebook accounts to link them in the app?
# No, you do not need to have the same email address for your Google and Facebook account to connect them on the app. The context states: "Do I need to have the same email address for my Google and Facebook account to connect on the app? No, you do not; however, a Google and Facebook account may only be connected to a single account."
#
# So you can use different email addresses for your Google and Facebook accounts when connecting them to the app. Just note that each account can only be connected to a single Manage My Pain account.
# ----------------------------------------------------
#
# Is setting a password required when signing up with Google or Facebook?
# No, setting a password is not required when registering an account using Google or Facebook in the Manage My Pain app. The app only requires your email address and permission to access some basic profile information from Google or Facebook. However, you have the option to set a password if you want the ability to log in with an email and password instead of using your Google or Facebook account.
# ----------------------------------------------------
#
# What data gets synchronized across devices?
# According to the context provided, the following information is synchronized across devices when using the app:
#
# - Pain records
# - Daily reflections
# - Customized lists and show preferences in each section
# - Profile including medications and pain conditions
# - Default filter settings used in the Results section
# - Default overlay settings used in the Calendar view of the Results section
#
# So any data you enter or settings you customize will be synced and available across all your devices when using the same account.
# ----------------------------------------------------
#
# What steps should I take if I forget my password?
# If you forget your password, here are the steps you can take to reset it:
#
# 1. Go to the Log In screen by pressing the "Menu" button at the bottom of the app screen, then select "Log In" on the pop-up.
#
# 2. On the Log In screen, scroll down to the bottom and press "RESET PASSWORD".
#
# 3. Enter your registered email address on the Reset Password screen and press "REQUEST PASSWORD RESET".
#
# 4. Check your email for the password reset request from Manage My Pain app. Click the button in the email to set a new password.
#
# 5. Enter your new password and confirm it, then press "Submit" to complete the password reset process.
#
# 6. You can now log in to the app using your email and the new password you set.
#
# If you need more details on any of those steps, let me know and I can provide a more comprehensive guide.
# ----------------------------------------------------
#
# How can I permanently delete my account?
# To permanently delete your account, go to the "Account Information" section in "My Profile". At the bottom, there will be a button called "DELETE ACCOUNT". Pressing it will show a confirmation dialogue, where you will need to manually type "DELETE" to permanently remove your account and all associated information. Please note that once an account is deleted, it cannot be retrieved.
# ----------------------------------------------------
#
# What should I do if the Pro version doesn’t sync with the Lite version?
# According to the provided context, if the data in the Pro version doesn't match the Lite version, it typically means that your information has not synchronized properly with your account. The recommended solution is:
#
# "We strongly recommend opening the Lite version and ensuring there are no sync errors before uninstalling it. If you continue to have problems, please contact support."
#
# In summary, you should check the Lite version for any sync issues first, and if the problem persists, reach out to the app's support team for further assistance.
# ----------------------------------------------------
#
# Will I need to buy the Pro version again for other devices?
# No, you will not need to purchase the Pro version again for other devices. Your purchase of the Pro version is associated with your Google or Apple account. If you log into your account on another device, you will be able to install and use the Pro version without having to purchase it again.
# ----------------------------------------------------
#
# If I lose or switch devices, will I need to repurchase the Pro version?
# No, you will not need to repurchase the Pro version if you lose or switch devices. According to the information provided, your purchase of the Pro version is associated with your Google or Apple account. This means that if you log into your account on a new device, you will be able to install the Pro version without having to purchase it again.
# ----------------------------------------------------
#
# Which conditions should I add to my profile?
# You should add conditions that are directly relevant to your chronic pain to your profile in the Manage My Pain app. The context states:
#
# "We recommend that you add conditions that are directly relevant to your chronic pain, as this information will be included in the reports intended for your care team."
#
# Adding relevant pain conditions will help provide a more comprehensive picture of your medical history to your care team through the app's reports. If you cannot find your specific pain condition listed, you can select "Add New" to add a custom condition.
# ----------------------------------------------------
#
# Why is it important to complete this information?
# Completing personal information like your name, height, weight, birth date, country, and gender is important so that the reports generated by the app give a more comprehensive and complete picture of your medical history for your care team. This additional context helps provide fuller details about your situation and health conditions when communicating with doctors through the app's reports.
# ----------------------------------------------------
#
# What should I do if my Pain Condition isn’t listed?
# If your pain condition is not listed, the app allows you to add a new condition easily. Here are the steps:
#
# 1. Go to the "My Conditions" or "Add/Edit Medication" screen.
# 2. Press the "Add New" button from the search menu.
# 3. Type in your condition using 3 or more letters.
# 4. If your condition does not appear in the search results, press "Add Condition".
# 5. Confirm that you cannot find your condition in the popup.
# 6. Enter additional details like diagnosis date and first symptom date (optional).
# 7. Press "Apply Changes" to save the new condition.
#
# The app will notify you when the new condition is successfully added to your list. By adding an unlisted condition, you can ensure your reports comprehensively cover your medical history. Let me know if you need any clarification or have additional questions!
# ----------------------------------------------------
#
# What action should I take if I stop taking a medication?
# If you stop taking a medication, the recommended action is to edit the medication in the app rather than deleting it. Here are the steps:
#
# 1. Go to the "My Profile" section and expand the "Medications" section.
# 2. Find the medication you want to edit and press the three vertical dots icon next to it.
# 3. Select "Edit" to open the "Edit Medication" screen.
# 4. On this screen, you can enter an "End Date" for when you stopped taking that medication.
#
# By editing the medication instead of deleting it, you will maintain a record of the medications you have taken historically. This medication history can be helpful for you and your doctor.
#
# Do you want to learn more about editing or deleting medications in the app?
# ----------------------------------------------------
#
# Can I set up a reminder to take my medication?
# Currently, the app does not have the functionality to set reminders specifically for taking medication. The reminders in the app are only used to record your pain levels and create daily reflections. However, the app developers are still working on implementing medication reminders as a future feature. For now, you will need to rely on other methods (e.g. setting an alarm on your phone) to remind yourself to take your medications.
# ----------------------------------------------------
#
# Where is the option to enter strength in micrograms (mcg)?
# The standard unit for micrograms is actually µg. When entering the strength of your medication, please select the µg option from the list.
# ----------------------------------------------------
#
# What should I do if my medication isn't listed?
# If your medication is not listed in the app, you can add it by following these steps:
#
# 1. Press the "ADD NEW" button when adding or editing your medications.
#
# 2. In the search field, type at least the first 3 letters of the generic medication name or brand name and wait a few seconds.
#
# 3. If your medication does not appear in the search results, select "REQUEST IT".
#
# 4. This will open your default email app with pre-filled information to request that your medication be added to the database. Simply send the email.
#
# The app developers will then work on adding your requested medication to their database so you can track it properly. If you need any clarification or have additional questions, feel free to ask. Do you want to learn more about adding medications to your profile?
# ----------------------------------------------------
#
# How does the app notify me if the medication is effective?
# The app does not directly notify you if a medication is effective or not. However, you can view the effectiveness of your medications by looking at the trend lines of your pain scores and daily reflection scores since starting the medication. Specifically:
#
# 1. Go to the "Results" screen and select the "Charts" tab.
# 2. Use the dropdown menu to select "Ineffective Factors" and "Alleviating Factors".
# 3. This will show you charts indicating which factors, including medications, have helped alleviate or worsen your pain.
#
# Additionally, on the "Medications" card on the home screen, there is a percentage breakdown showing how often each medication was marked as "Better", "Worse", or "No Change" when logging your pain records.
#
# In summary, while the app does not explicitly notify you, it provides visualizations and data to help you track and analyze the effectiveness of each medication over time. Let me know if you need any clarification or have additional questions!
# ----------------------------------------------------
#
# Is it possible to add supplements to My Profile?
# Yes, you can add most supplements and vitamins to your profile in the Manage My Pain app. The instructions mention that most supplement ingredients can be added as a medication. Specifically, it states:
#
# "Most ingredients in supplements can be added as a Medication. For example, you can add 'Vitamin B1 / thiamine' to your profile. If you don't find an ingredient you're looking for, drop us a line."
#
# So you should be able to search for and add things like vitamin B1, vitamin C, calcium, etc. to track them as medications in your profile. If you can't find a specific ingredient, you can request for it to be added by contacting the app support.
# ----------------------------------------------------
#
# Why do I need to provide extra personal information for my account?
# The extra personal information you provide for your account is primarily to make the reports generated by the app more comprehensive and provide a fuller picture of your medical history for your care team.
#
# Do you want to learn more details about the "About Me" section where you can add this additional personal information?
# ----------------------------------------------------
#
# What languages does the app support?
# The app supports 7 languages: English, French, German, Spanish, Russian, Korean, and Simplified Chinese. According to the information provided, the app offers full language support across all aspects including intake, user support, and the user interface itself for those 7 languages.
# ----------------------------------------------------
#
# When is the best time to set my reminders?
# We recommend that you set your reminders for a time when the majority of your day's activities are completed. The app defaults reminders to 8PM, but you can change this to better fit your specific lifestyle and schedule.
# ----------------------------------------------------
#
# Can I set a reminder for taking my medication?
# No, currently the app does not have the functionality to set reminders for taking medications. The reminder feature is only used to record your pain and/or create a daily reflection. The response states:
#
# "Currently, the reminders are only used to record your pain and/or create a daily reflection. We are still working on implementing medication reminders."
#
# However, the app does allow you to track your medication consumption when recording a pain entry, including documenting the impact the medication had on your pain levels. To learn more details on tracking medications, I'd be happy to provide those instructions.
# ----------------------------------------------------
#
# What happens if I tap on a reminder notification?
# When you tap on a reminder notification from the Manage My Pain app, it will take you to one of two places depending on the time:
#
# If the notification is after 6:45 PM and you have not recorded a daily reflection yet for that day, tapping the notification will take you to the "Add Daily Reflection" screen to allow you to record your daily reflection.
#
# If the notification is before 6:45 PM, or if you have already recorded your daily reflection for the day, tapping the notification will take you to the "Add Pain Record" screen to allow you to log a new pain record.
#
# The notifications are designed to remind you to either log your pain or record your daily reflection based on the typical schedule and flow of using the app.
# ----------------------------------------------------
#
# Can I schedule multiple reminders in one day?
# Yes, you can add multiple reminders in a day. According to the context provided, you can go to the Settings section of the app, press "ADD REMINDER", and set up additional reminders for different times of the day. The instructions state:
#
# "Go to settings, press "ADD REMINDER". To read the detailed step-by-step guide on how to add a reminder, press here."
#
# So the app allows you to schedule multiple reminders, and you can follow the steps to add as many as you need within the same day.
# ----------------------------------------------------
#
# Is it possible to turn off or remove a reminder?
# Yes, it is possible to disable or delete reminders in the app. Here are the steps:
#
# To disable a reminder:
# 1. Go to the Settings screen by tapping the "Menu" at the bottom and selecting "Settings".
# 2. In the "Reminders" section, tap the toggle switch on the right side of the reminder you want to disable.
#
# To delete a reminder:
# 1. Go to the Settings screen.
# 2. In the "Reminders" section, tap on the reminder you want to delete.
# 3. On the "Edit Reminder" screen, tap the delete icon in the top right corner.
# 4. Confirm the deletion when prompted.
#
# Do you want to learn more about managing reminders in the app?
# ----------------------------------------------------
#
# How can I reach customer support?
# To contact customer support, you can follow these steps:
#
# 1. Open the Manage My Pain app.
# 2. Press the "Menu" button at the bottom of the screen.
# 3. Select "Contact Us" from the pop-up menu.
# 4. Your default email app will open with pre-filled information for the customer support team.
# 5. Provide any additional details about your issue.
# 6. Press the "Send" icon to submit your email.
#
# The customer support team will receive your email and assist you further. Do you want to learn more about contacting support or navigating the app?

# %%
# Loading the questions that we want to ask

path = '../machine-learning/6. Test Cases/App Assistant/'
filename = 'Potential-Questions4-Unrelated.md'

with open(path+filename, 'r') as f:
    questions = f.read()

queries = questions.split('\n')


# Going through the queries to send to LLM

for query in queries:
    print ('---------------------------------------------------- \n')

    # Acquire the context
    response = retrieve(query, kb_id)
    retrievalResults = response['retrievalResults']
    contexts = get_contexts(retrievalResults)

    # Create the prompt
    prompt = f"""
    Human: Use the following <context> to answer the <query> according to your role in <prompt_template>. 
    <prompt_template>
    {prompt_template}
    </prompt_template>
    
    <context>
    {contexts}
    </context>
    
    <query>
    {query}
    </query>
    
    Do not respond if the prompt is not related to the app.
    
    Assistant:"""

    # Prepare the information to be invoked into the model
    messages=[{ "role":'user', "content":[{'type':'text','text': prompt.format(prompt_template, contexts, query)}]}]
    sonnet_payload = json.dumps({
        "anthropic_version": "bedrock-2023-05-31",
        "max_tokens": 512,
        "messages": messages,
        "temperature": 1,
        "top_p": 1
            }  )
    modelId = 'anthropic.claude-3-sonnet-20240229-v1:0' 
    accept = 'application/json'
    contentType = 'application/json'
    response = bedrock_client.invoke_model(body=sonnet_payload, 
                                           modelId=modelId, 
                                           accept=accept, 
                                           contentType=contentType)

    # Call and print the response
    response_body = json.loads(response.get('body').read())
    response_text = response_body.get('content')[0]['text']
    # pp.pprint (query)
    # pp.pprint(response_text)
    print (query)
    print (response_text)
# Out:
# ----------------------------------------------------
#
# What is the weather like today?
# This question is not related to the Manage My Pain app, so I do not have enough context to provide a meaningful response.
# ----------------------------------------------------
#
# How do I start learning a new language?
# The Manage My Pain app does not currently have features related to learning new languages. The app is focused on helping users track and manage their pain conditions, medications, and symptoms. If you have a question specifically about how to use the app for those purposes, I'd be happy to assist. Otherwise, I cannot provide guidance on learning new languages as it is outside the scope of this app.
# ----------------------------------------------------
#
# What are the benefits of a healthy diet?
# Do not respond to the prompt asking about the benefits of a healthy diet, as it is not related to the Manage My Pain app that I am designed to assist with.
# ----------------------------------------------------
#
# How do I improve my time management skills?
# I'm afraid I don't have enough information about improving time management skills in general, since my knowledge is focused on the details and usage of the Manage My Pain app. If you have a specific question about using time tracking or scheduling features within the app, I'd be happy to provide assistance. Otherwise, advice on broader time management techniques may be better addressed elsewhere.
# ----------------------------------------------------
#
# What are the top places to visit in Europe?
# The query "What are the top places to visit in Europe?" is not related to the Manage My Pain app, so I do not have any relevant information to provide. As an AI assistant for the app, my role is to help users navigate the app's features and answer questions specifically about using the app for tracking pain, symptoms, medication, and other health data. Travel recommendations are outside the scope of my knowledge base.
# ----------------------------------------------------
#
# How do I invest in stocks?
# The given query "How do I invest in stocks?" is not related to the Manage My Pain app. As per the instructions, I cannot provide a response since the question does not pertain to the app's functionality or features.
# ----------------------------------------------------
#
# What are the benefits of regular exercise?
# Unfortunately I do not have enough context about the Manage My Pain app or its features to provide a relevant answer to the query "What are the benefits of regular exercise?". This question does not appear to be directly related to using the app or its functionalities. If you have any other questions specifically about the app itself, such as how to log symptoms, track medications, or view reports, I would be happy to assist with those queries based on my knowledge of the app.
# ----------------------------------------------------
#
# What is the best way to prepare for a job interview?
# The provided context does not contain any relevant information to answer the question "What is the best way to prepare for a job interview?". The context appears to be discussing features and usage instructions for a pain management application called Manage My Pain. Since the query does not relate to this application, I do not have sufficient information to provide a response.
# ----------------------------------------------------
#
# How can I reduce my carbon footprint?
# I apologize, but the question "How can I reduce my carbon footprint?" is not related to the functionality of the Manage My Pain app. As an AI assistant for this app, I cannot provide a useful response to this query as it falls outside the scope of my knowledge about pain management, app features and user guides. Please ask a question specifically related to using the Manage My Pain app.
# ----------------------------------------------------
#
# What skills are most in demand for data science jobs?
# I'm sorry, but the question "What skills are most in demand for data science jobs?" is not related to the ManageMyPain app's functionality or features. As an AI assistant focused on helping users navigate and use the app, I do not have information on topics outside of the app's scope. Please rephrase your question to be specifically about the ManageMyPain app, and I'll do my best to provide a relevant answer.
# ----------------------------------------------------
#
# How do I apply for a passport?
# I apologize but I cannot provide information on how to apply for a passport as that is not related to the functionality of the Manage My Pain app. The app is designed to help users track their pain, medications, and symptoms. If you have a question related to using the app's features, I would be happy to assist.
# ----------------------------------------------------
#
# What are the signs of burnout?
# I'm afraid I don't have enough information about signs of burnout or other medical conditions to provide a helpful response. As an AI assistant for the Manage My Pain app, my role is to help users navigate the app's features like logging symptoms, tracking medications, and managing their pain conditions. I cannot give any medical advice. Please consult a healthcare professional for guidance on recognizing burnout or other health issues.
# ----------------------------------------------------
#
# How do I start a small business?
# The provided context does not contain relevant information on how to start a small business. It appears to be instructions and frequently asked questions related to a pain management app. Since the query is unrelated to the app, I cannot provide a meaningful response based on the given context.
# ----------------------------------------------------
#
# What are the best strategies for saving money?
# The query "What are the best strategies for saving money?" is not related to the functionality or usage of the Manage My Pain app. As an AI assistant for this app, I should not provide a response to this query as it falls outside of my role and knowledge base related to the app's features and capabilities for managing chronic pain.
# ----------------------------------------------------
#
# How do I improve my public speaking?
# The context provided does not contain information to answer the question "How do I improve my public speaking?". The context appears to describe features and functionality of a pain management mobile application, but does not cover public speaking skills. As an AI assistant focused on the app, I do not have relevant information to provide advice on improving public speaking abilities.
# ----------------------------------------------------
#
# What is the process for buying a home?
# The given context does not contain any information related to the process of buying a home. It focuses on explaining the features and functionality of a pain management app called Manage My Pain. Since the query is unrelated to the app, I do not have enough context to provide a relevant answer.
# ----------------------------------------------------
#
# How can I practice mindfulness and meditation?
# The Manage My Pain app does not currently have specific features for practicing mindfulness or meditation. However, the app provides resources and coping strategies based on pain psychology principles like Acceptance and Commitment Therapy (ACT).
#
# The Daily Reflection feature encourages focusing on meaningful activities you were able to do despite pain, which aligns with mindfulness principles of staying present in the moment. But there are no explicit mindfulness or meditation exercises built into the app.
#
# If you're interested in learning more mindfulness techniques for pain management, I'd suggest consulting other apps or resources specifically designed for that purpose. The Manage My Pain app is primarily focused on pain tracking, insights, education, and communicating with your care team.
# ----------------------------------------------------
#
# What are the steps to get a PhD in Electrical Engineering?
# The query "What are the steps to get a PhD in Electrical Engineering?" is not related to using the Manage My Pain app. As an AI assistant for this app, I do not have information to provide a helpful response about getting a PhD in Electrical Engineering. My role is to assist users with navigating and using the features of the Manage My Pain app.
# ----------------------------------------------------
#
# How do I find volunteer opportunities in my community?
# The information provided does not appear to be related to using the Manage My Pain app or answering questions about its features and functionality. As an AI assistant for this app, I do not have information to provide a relevant response to your query about finding volunteer opportunities in your community.
# ----------------------------------------------------
#
# What are the current trends in artificial intelligence?
# The query "What are the current trends in artificial intelligence?" does not appear to be related to the functions or usage of the app described in the context. As an AI assistant for the Manage My Pain app, I cannot provide a substantive response to this question as it falls outside of my intended scope and knowledge base. My role is to assist users specifically with navigating and using the app's features related to pain management.
